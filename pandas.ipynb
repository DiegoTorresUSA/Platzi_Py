# %%
import pandas as pd

# %%
pd.Series(['Navas', 'Mbappe', 'Neymar', 'Messi'])
# Out:
# 0     Navas
# 1    Mbappe
# 2    Neymar
# 3     Messi
# dtype: object

# %%
psg_players = pd.Series(['Navas', 'Mbappe', 'Neymar', 'Messi'],
         index=[1,7,10,30])

# %%
psg_players
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
dict = {1: 'Navas', 7:'Mbappe', 10:'Neymar', 30:'Messi'}

# %%
pd.Series(dict)
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
psg_players[10]
# Out:
# 'Neymar'

# %%
psg_players[30]
# Out:
# 'Messi'

# %%
psg_players[2:]
# Out:
# 10    Neymar
# 30     Messi
# dtype: object

# %%
df= pd.read_csv('pandas_numpy/texto.csv',sep=';', header=0, encoding = 'unicode_escape', engine ='python')

# %%
df
# Out:
#           ï»¿name     id nametype              recclass mass (g)   fall  \
# 0          Aachen      1    Valid                    L5       21   Fell
# 1          Aarhus      2    Valid                    H6      720   Fell
# 2            Abee      6    Valid                   EH4      107   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1,914   Fell
# 4         Achiras    370    Valid                    L6      780   Fell
# ...           ...    ...      ...                   ...      ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite      172  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped       46  Found
# 45713        Zlin  30410    Valid                    H4      3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2,167  Found
# 45715  Zulu Queen  30414    Valid                  L3.7      200  Found
#
#          year      reclat      reclong             GeoLocation
# ...

# %%
df.to_csv('pandas_numpy/Meteorites.csv')

# %%
df
# Out:
#           ï»¿name     id nametype              recclass mass (g)   fall  \
# 0          Aachen      1    Valid                    L5       21   Fell
# 1          Aarhus      2    Valid                    H6      720   Fell
# 2            Abee      6    Valid                   EH4      107   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1,914   Fell
# 4         Achiras    370    Valid                    L6      780   Fell
# ...           ...    ...      ...                   ...      ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite      172  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped       46  Found
# 45713        Zlin  30410    Valid                    H4      3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2,167  Found
# 45715  Zulu Queen  30414    Valid                  L3.7      200  Found
#
#          year      reclat      reclong             GeoLocation
# ...

# %%
df.sample(15)
# Out:
#                            ï»¿name     id nametype           recclass  \
# 34224  Queen Alexandra Range 97590  21046    Valid                LL5
# 44265                Yamato 981784  38406    Valid                 H6
# 26350                      Naviska  48657    Valid  Iron, IAB complex
# 12695        Graves Nunataks 06144  49533    Valid                 L6
# 3057            Allan Hills A80101   1929    Valid                 L6
# 42315                Yamato 794066  29020    Valid                 H4
# 31058              Ãsterplana 045  44845   Relict          Relict OC
# 18928         LaPaz Icefield 04800  45298    Valid                 L5
# 1045                     Varre-Sai  53633    Valid                 L5
# 26226            Mount Pratt 04409  44561    Valid                LL6
# 32967  Queen Alexandra Range 93712  19798    Valid                 L6
# 45664                Yaringie Hill  48950    Valid                 H5
# ...

# %%
df.describe()
# Out:
#                  id          year        reclat       reclong
# count  45716.000000  45425.000000  3.840100e+04  3.840100e+04
# mean   26889.735104   1991.828817 -3.912258e+07  6.107432e+07
# std    16860.683030     25.052766  4.637851e+07  8.064730e+07
# min        1.000000    860.000000 -8.736667e+07 -1.654333e+08
# 25%    12688.750000   1987.000000 -7.671424e+07  0.000000e+00
# 50%    24261.500000   1998.000000 -7.150000e+07  3.566667e+07
# 75%    40656.750000   2003.000000  0.000000e+00  1.571667e+08
# max    57458.000000   2101.000000  8.116667e+07  3.544733e+08

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (45716, 10)

# %%
df.size
# Out:
# 457160

# %%
df
# Out:
#           ï»¿name     id nametype              recclass mass (g)   fall  \
# 0          Aachen      1    Valid                    L5       21   Fell
# 1          Aarhus      2    Valid                    H6      720   Fell
# 2            Abee      6    Valid                   EH4      107   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1,914   Fell
# 4         Achiras    370    Valid                    L6      780   Fell
# ...           ...    ...      ...                   ...      ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite      172  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped       46  Found
# 45713        Zlin  30410    Valid                    H4      3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2,167  Found
# 45715  Zulu Queen  30414    Valid                  L3.7      200  Found
#
#          year      reclat      reclong             GeoLocation
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           ï»¿name     id nametype              recclass mass (g)   fall  \
# 0          Aachen      1    Valid                    L5       21   Fell
# 1          Aarhus      2    Valid                    H6      720   Fell
# 2            Abee      6    Valid                   EH4      107   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1,914   Fell
# 4         Achiras    370    Valid                    L6      780   Fell
# ...           ...    ...      ...                   ...      ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite      172  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped       46  Found
# 45713        Zlin  30410    Valid                    H4      3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2,167  Found
# 45715  Zulu Queen  30414    Valid                  L3.7      200  Found
#
#          year      reclat      reclong             GeoLocation
# ...

# %%
df.describe()
# Out:
#                  id          year        reclat       reclong
# count  45716.000000  45425.000000  3.840100e+04  3.840100e+04
# mean   26889.735104   1991.828817 -3.912258e+07  6.107432e+07
# std    16860.683030     25.052766  4.637851e+07  8.064730e+07
# min        1.000000    860.000000 -8.736667e+07 -1.654333e+08
# 25%    12688.750000   1987.000000 -7.671424e+07  0.000000e+00
# 50%    24261.500000   1998.000000 -7.150000e+07  3.566667e+07
# 75%    40656.750000   2003.000000  0.000000e+00  1.571667e+08
# max    57458.000000   2101.000000  8.116667e+07  3.544733e+08

# %%
pd.options.display.float_format = '{:.1f}'.format

# %%
df
# Out:
#           ï»¿name     id nametype              recclass mass (g)   fall  \
# 0          Aachen      1    Valid                    L5       21   Fell
# 1          Aarhus      2    Valid                    H6      720   Fell
# 2            Abee      6    Valid                   EH4      107   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1,914   Fell
# 4         Achiras    370    Valid                    L6      780   Fell
# ...           ...    ...      ...                   ...      ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite      172  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped       46  Found
# 45713        Zlin  30410    Valid                    H4      3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2,167  Found
# 45715  Zulu Queen  30414    Valid                  L3.7      200  Found
#
#         year      reclat      reclong             GeoLocation
# ...

# %%
df.describe()
# Out:
#            id    year      reclat      reclong
# count 45716.0 45425.0     38401.0      38401.0
# mean  26889.7  1991.8 -39122580.3   61074318.5
# std   16860.7    25.1  46378511.4   80647298.1
# min       1.0   860.0 -87366670.0 -165433330.0
# 25%   12688.8  1987.0 -76714240.0          0.0
# 50%   24261.5  1998.0 -71500000.0   35666670.0
# 75%   40656.8  2003.0         0.0  157166670.0
# max   57458.0  2101.0  81166670.0  354473330.0

# %%
df.dtypes
# Out:
# ï»¿name          object
# id                int64
# nametype       category
# recclass         object
# mass (g)         object
# fall           category
# year            float64
# reclat          float64
# reclong         float64
# GeoLocation      object
# dtype: object

# %%
df.convert_dtypes().dtypes
# Out:
# ï»¿name        string
# id              Int64
# nametype       string
# recclass       string
# mass (g)       string
# fall           string
# year            Int64
# reclat          Int64
# reclong         Int64
# GeoLocation    string
# dtype: object

# %%
df.nunique()
# Out:
# ï»¿name        45716
# id             45716
# nametype           2
# recclass         466
# mass (g)       12370
# fall               2
# year             265
# reclat         12738
# reclong        14640
# GeoLocation    17100
# dtype: int64

# %%
df[['fall', 'nametype']].astype('category')
# Out:
#         fall nametype
# 0       Fell    Valid
# 1       Fell    Valid
# 2       Fell    Valid
# 3       Fell    Valid
# 4       Fell    Valid
# ...      ...      ...
# 45711  Found    Valid
# 45712  Found    Valid
# 45713  Found    Valid
# 45714  Found    Valid
# 45715  Found    Valid
#
# [45716 rows x 2 columns]

# %%
df[['fall', 'nametype']] = df[['fall', 'nametype']].astype('category')

# %%
df['fall'].unique()
# Out:
# ['Fell', 'Found']
# Categories (2, object): ['Fell', 'Found']

# %%
df['fall'].value_counts()
# Out:
# Found    44609
# Fell      1107
# Name: fall, dtype: int64
