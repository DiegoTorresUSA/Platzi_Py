# %%
import pandas as pd

# %%
df_datos = pd.read_csv('Stats_Min/Traza_ARL_fasecolda.csv', sep=';', header=0)

# %%
df_datos.head(10)
# Out:
#           ID           FechaOperacion  ServicioOrigen  ServicioDestino  \
# 0  380073807  2022-02-21 05:22:19.297            1001             1002
# 1  380073810  2022-02-21 05:22:20.833            1001             1002
# 2  380073813  2022-02-21 05:22:22.207            1001             1002
# 3  380073819  2022-02-21 05:22:24.053            1001             1002
# 4  380073825  2022-02-21 05:22:29.183            1001             1002
# 5  380073829  2022-02-21 05:22:30.590            1001             1002
# 6  380073836  2022-02-21 05:22:33.907            1001             1002
# 7  380073839  2022-02-21 05:22:35.190            1001             1002
# 8  380073854  2022-02-21 05:22:38.043            1001             1002
# 9  380073872  2022-02-21 05:22:39.447            1001             1002
#
#                           Identificador  \
# 0  BAAD7DFB-3787-4623-BC45-856C503ECBA9
# 1  862A0123-C697-482A-9613-9BFF642DD39F
# 2  459EA6AD-50E1-4BB4-9FF0-8BE8BB1FEBEB
# ...

# %%
df_datos.sort_values('FechaOperacion', ascending = True)
# Out:
#                 ID           FechaOperacion  ServicioOrigen  ServicioDestino  \
# 0        380073807  2022-02-21 05:22:19.297            1001             1002
# 1        380073810  2022-02-21 05:22:20.833            1001             1002
# 2        380073813  2022-02-21 05:22:22.207            1001             1002
# 3        380073819  2022-02-21 05:22:24.053            1001             1002
# 4        380073825  2022-02-21 05:22:29.183            1001             1002
# ...            ...                      ...             ...              ...
# 3858575  408808256  2022-03-09 23:59:57.583           12001            12002
# 3858576  408808258  2022-03-09 23:59:57.693           12001            12002
# 3858577  408808260  2022-03-09 23:59:57.833           12001            12002
# 3858578  408808263  2022-03-09 23:59:58.037            8001             8002
# 3858579  408808269  2022-03-09 23:59:59.287            8001             8002
#
# ...

# %%
df_datos[df_datos['FechaOperacion'] <= '2022-02-21']
# Out:
# Empty DataFrame
# Columns: [ID, FechaOperacion, ServicioOrigen, ServicioDestino, Identificador, DatosOperacion, DatosRespuesta, MetaDatos]
# Index: []
