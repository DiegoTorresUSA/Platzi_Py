# %%
import pandas as pd

# %%
df_estadistica = pd.read_csv('pandas_numpy/DetalleEstadisticas.csv', sep=';', header=0)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 df_estadistica = pd.read_csv('pandas_numpy/DetalleEstadisticas.csv', sep=';', header=0)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df_estadistica = pd.read_csv('pandas_numpy/DetalleEstadisticas.csv', sep=';', header=0, encoding = 'unicode_escape', engine ='python')

# %%
df_estadistica
# Out:
#       Fecha_Operacion  Codigo Servicio Codigo CCF  \
# 0           1/01/2022            80204      CCF39
# 1           1/01/2022            80204      CCF39
# 2           1/01/2022            80204      CCF39
# 3           1/01/2022            80204      CCF39
# 4           1/01/2022            80204      CCF39
# ...               ...              ...        ...
# 65884       8/05/2022            80203      CCF39
# 65885       8/05/2022            80203      CCF39
# 65886       8/05/2022            80204      CCF03
# 65887       8/05/2022            80204      CCF03
# 65888       8/05/2022            80204      CCF03
#
#                                                Resultado Codigo  Cantidad  \
# 0      El empleador no tiene una afiliacion vigente p...   GN11      2983
# 1       El reporte ha sido registrado satisfactoriamente    200       316
# 2      El valor del Número de Documento no cumple con...   GE02        74
# ...

# %%
df_estadistica.describe()
# Out:
#        Codigo Servicio       Cantidad
# count     65889.000000   65889.000000
# mean      69714.991167     176.477849
# std       22989.792505    1508.481494
# min       19001.000000       1.000000
# 25%       80101.000000       1.000000
# 50%       80101.000000       1.000000
# 75%       80203.000000       5.000000
# max       80204.000000  108193.000000

# %%
df_estadistica.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65889 entries, 0 to 65888
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Fecha_Operacion  65889 non-null  object
#  1   Codigo Servicio  65889 non-null  int64
#  2   Codigo CCF       65889 non-null  object
#  3   Resultado        65885 non-null  object
#  4   Codigo           65885 non-null  object
#  5   Cantidad         65889 non-null  int64
#  6   Nombre servicio  65889 non-null  object
#  7   CCF              65889 non-null  object
#  8   trimestre        65889 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 4.5+ MB

# %%
df_estadistica[CCF].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 df_estadistica[CCF].value_counts()
#
# NameError: name 'CCF' is not defined

# %%
df_estadistica['CCF'].value_counts()
# Out:
# CAJASAN                                                                      38703
# COMFAMILIAR ANDI                                                              2922
# COMPENSAR   E.P.S.                                                            1725
# CAJA DE COMPENSACION FAMILIAR DEL MAGDALENA                                   1614
# CAJA DE COMPENSACION FAMILIAR DE ANTIOQUIA COMFAMA                            1588
# CAJA DE COMPENSACION FAMILIAR COMFENALCO ANTIOQUIA                            1527
# CAJA DE COMPENSACIÓN FAMILIAR DE NARIÑO                                       1428
# CAJA DE COMPENSACIÓN FAMILIAR DE LA GUAJIRA "COMFAGUAJIRA"                    1181
# CAJA DE COMPENSACION FAMILIAR DE CALDAS                                       1136
# CAJA COLOMBIANA DE SUBSIDIO FAMILIAR COLSUBSIDIO                               998
# COMFACESAR                                                                     996
# ...
