# %%
import pandas as pd

# %%
df_arl = pd.read_csv('SURA/arl19_22_Mayo.csv', sep=';', header=0, encoding = 'unicode_escape', engine ='python')

# %%
df_arl.head(10)
# Out:
#           ID   FechaOperacion  ServicioOrigen  ServicioDestino  \
# 0  540137257  16/05/2022 1:39            1001             1002
# 1  540137262  16/05/2022 1:39            1001             1002
# 2  540137268  16/05/2022 1:39            1001             1002
# 3  540137276  16/05/2022 1:39            1001             1002
# 4  540137285  16/05/2022 1:39            1001             1002
# 5  540137288  16/05/2022 1:39            1001             1002
# 6  540137298  16/05/2022 1:39            1001             1002
# 7  540137302  16/05/2022 1:39            1001             1002
# 8  540137310  16/05/2022 1:39            1001             1002
# 9  540137315  16/05/2022 1:39            1001             1002
#
#                           Identificador  DatosOperacion.IdArl  \
# 0  0DD83FAC-B7A3-436D-809B-E110932B7974                  43.0
# 1  54278FCA-FDEA-4A0E-89F5-F8A6702D3AA2                  43.0
# 2  1580CE13-DC38-4D41-82AF-4244DB93E0DD                  43.0
# ...

# %%
df_arl.columns
# Out:
# Index(['ID', 'FechaOperacion', 'ServicioOrigen', 'ServicioDestino',
#        'Identificador', 'DatosOperacion.IdArl',
#        'DatosOperacion.UsuarioCreacion', 'DatosOperacion.IpCreacion',
#        'DatosOperacion.Identificador', 'DatosOperacion.CodigoARL',
#        'DatosOperacion.TipoDocumentoEmpleador',
#        'DatosOperacion.NumeroDocumentoEmpleador',
#        'DatosOperacion.ConsecutivoNITEmpleador', 'DatosOperacion.TipoPersona',
#        'DatosOperacion.NaturalezaJuridica', 'DatosOperacion.TipoAportante',
#        'DatosOperacion.RazonSocialEmpleador',
#        'DatosOperacion.PrimerNombreEmpleador',
#        'DatosOperacion.PrimerApellidoEmpleador',
#        'DatosOperacion.CorreoEmpleador', 'DatosOperacion.ActividadEconomica',
#        'DatosOperacion.ClaseAportante',
#        'DatosOperacion.TipoDocumentoRepresentante',
#        'DatosOperacion.NumeroDocumentoRepresentante',
#        'DatosOperacion.PrimerNombreRepresentante',
# ...

# %%
df_arl['DatosOperacion.IdArl'] == 43.0
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 993458    False
# 993459    False
# 993460    False
# 993461    False
# 993462    False
# Name: DatosOperacion.IdArl, Length: 993463, dtype: bool

# %%
df_arl[df_arl['DatosOperacion.IdArl'] == 42.0]
# Out:
#                ID    FechaOperacion  ServicioOrigen  ServicioDestino  \
# 9633    540197807   16/05/2022 5:05            7001             7002
# 9634    540197808   16/05/2022 5:05            7001             7002
# 9638    540197839   16/05/2022 5:05            7001             7002
# 9641    540197864   16/05/2022 5:05            7001             7002
# 9644    540197890   16/05/2022 5:05            7001             7002
# ...           ...               ...             ...              ...
# 989671  549252318  21/05/2022 23:54           17001            17002
# 989672  549252332  21/05/2022 23:54           17001            17002
# 989673  549252343  21/05/2022 23:54           17001            17002
# 989674  549252347  21/05/2022 23:54           17001            17002
# 989676  549252356  21/05/2022 23:54           17001            17002
#
#                                Identificador  DatosOperacion.IdArl  \
# 9633    F84156F8-FD5C-4C7F-AB9E-9062E2880C83                  42.0
# ...

# %%
df.head(10)
# Out:
#           ID   FechaOperacion  ServicioOrigen  ServicioDestino  \
# 0  540137257  16/05/2022 1:39            1001             1002
# 1  540137262  16/05/2022 1:39            1001             1002
# 2  540137268  16/05/2022 1:39            1001             1002
# 3  540137276  16/05/2022 1:39            1001             1002
# 4  540137285  16/05/2022 1:39            1001             1002
# 5  540137288  16/05/2022 1:39            1001             1002
# 6  540137298  16/05/2022 1:39            1001             1002
# 7  540137302  16/05/2022 1:39            1001             1002
# 8  540137310  16/05/2022 1:39            1001             1002
# 9  540137315  16/05/2022 1:39            1001             1002
#
#                           Identificador  DatosOperacion.IdArl  \
# 0  0DD83FAC-B7A3-436D-809B-E110932B7974                  43.0
# 1  54278FCA-FDEA-4A0E-89F5-F8A6702D3AA2                  43.0
# 2  1580CE13-DC38-4D41-82AF-4244DB93E0DD                  43.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 993463 entries, 0 to 993462
# Data columns (total 42 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   ID                                           993463 non-null  int64
#  1   FechaOperacion                               993463 non-null  object
#  2   ServicioOrigen                               993463 non-null  int64
#  3   ServicioDestino                              993463 non-null  int64
#  4   Identificador                                993463 non-null  object
#  5   DatosOperacion.IdArl                         993029 non-null  float64
#  6   DatosOperacion.UsuarioCreacion               993029 non-null  float64
#  7   DatosOperacion.IpCreacion                    993029 non-null  object
#  8   DatosOperacion.Identificador                 993029 non-null  object
# ...

# %%
df['DatosOperacion.IdArl'].fillna(0)
# Out:
# 0         43.0
# 1         43.0
# 2         43.0
# 3         43.0
# 4         43.0
#           ...
# 993458    44.0
# 993459    44.0
# 993460    49.0
# 993461    44.0
# 993462    44.0
# Name: DatosOperacion.IdArl, Length: 993463, dtype: float64

# %%
df['DatosOperacion.IdArl'] = df['DatosOperacion.IdArl'].astype("int64")
df['DatosOperacion.IdArl'].fillna(0)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 df['DatosOperacion.IdArl'] = df['DatosOperacion.IdArl'].astype("int64")
#       2 df['DatosOperacion.IdArl'].fillna(0)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# ...

# %%
df['DatosOperacion.IdArl'] = df['DatosOperacion.IdArl'].fillna(0)

# %%
df['DatosOperacion.IdArl'].astype('int64')
# Out:
# 0         43
# 1         43
# 2         43
# 3         43
# 4         43
#           ..
# 993458    44
# 993459    44
# 993460    49
# 993461    44
# 993462    44
# Name: DatosOperacion.IdArl, Length: 993463, dtype: int64

# %%
df['DatosOperacion.IdArl'] == 42
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 993458    False
# 993459    False
# 993460    False
# 993461    False
# 993462    False
# Name: DatosOperacion.IdArl, Length: 993463, dtype: bool

# %%
df[df['DatosOperacion.IdArl'] == 42].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 df[df['DatosOperacion.IdArl'] == 42].astype('int64')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df[['ID', 'FechaOperacion', 'ServicioOrigen', 'DatosOperacion.IdArl', 'DatosOperacion.TipoDocumentoEmpleador', 'DatosOperacion.NumeroDocumentoEmpleador', 'DatosOperacion.TipoPersona', 'DatosRespuesta.mensaje', 'DatosRespuesta.codigo']]
# Out:
#                ID   FechaOperacion  ServicioOrigen  DatosOperacion.IdArl  \
# 0       540137257  16/05/2022 1:39            1001                  43.0
# 1       540137262  16/05/2022 1:39            1001                  43.0
# 2       540137268  16/05/2022 1:39            1001                  43.0
# 3       540137276  16/05/2022 1:39            1001                  43.0
# 4       540137285  16/05/2022 1:39            1001                  43.0
# ...           ...              ...             ...                   ...
# 993458  549288882  22/05/2022 2:01            1001                  44.0
# 993459  549288886  22/05/2022 2:01            1001                  44.0
# 993460  549288896  22/05/2022 2:01           12001                  49.0
# 993461  549288899  22/05/2022 2:01            1001                  44.0
# 993462  549288907  22/05/2022 2:01            1001                  44.0
#
#        DatosOperacion.TipoDocumentoEmpleador  \
# ...

# %%
cols_to_subset = ['ID', 'FechaOperacion', 'ServicioOrigen', 'DatosOperacion.IdArl', 'DatosOperacion.TipoDocumentoEmpleador', 'DatosOperacion.NumeroDocumentoEmpleador', 'DatosOperacion.TipoPersona', 'DatosRespuesta.mensaje', 'DatosRespuesta.codigo']

# %%
df[cols_to_subset],[cols_to_subset.DatosOperacion.IdArl == 42]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 df[cols_to_subset],[cols_to_subset.DatosOperacion.IdArl == 42]
#
# AttributeError: 'list' object has no attribute 'DatosOperacion'

# %%
equal_43 = df[df['DatosOperacion.IdArl'] == 42]

# %%
equal_43
# Out:
#                ID    FechaOperacion  ServicioOrigen  ServicioDestino  \
# 9633    540197807   16/05/2022 5:05            7001             7002
# 9634    540197808   16/05/2022 5:05            7001             7002
# 9638    540197839   16/05/2022 5:05            7001             7002
# 9641    540197864   16/05/2022 5:05            7001             7002
# 9644    540197890   16/05/2022 5:05            7001             7002
# ...           ...               ...             ...              ...
# 989671  549252318  21/05/2022 23:54           17001            17002
# 989672  549252332  21/05/2022 23:54           17001            17002
# 989673  549252343  21/05/2022 23:54           17001            17002
# 989674  549252347  21/05/2022 23:54           17001            17002
# 989676  549252356  21/05/2022 23:54           17001            17002
#
#                                Identificador  DatosOperacion.IdArl  \
# 9633    F84156F8-FD5C-4C7F-AB9E-9062E2880C83                  42.0
# ...

# %%
equal_43.to_csv('SURA/datagy42.csv', index=False, header=True)

# %%
equal_43.head(5)
# Out:
#              ID   FechaOperacion  ServicioOrigen  ServicioDestino  \
# 9633  540197807  16/05/2022 5:05            7001             7002
# 9634  540197808  16/05/2022 5:05            7001             7002
# 9638  540197839  16/05/2022 5:05            7001             7002
# 9641  540197864  16/05/2022 5:05            7001             7002
# 9644  540197890  16/05/2022 5:05            7001             7002
#
#                              Identificador  DatosOperacion.IdArl  \
# 9633  F84156F8-FD5C-4C7F-AB9E-9062E2880C83                  42.0
# 9634  15F2CA36-9679-4418-B331-9E8EC8886054                  42.0
# 9638  80AE6A58-EE16-4BDE-AD78-A3488477237D                  42.0
# 9641  D5E40FF7-EB7D-43F5-BBB0-76B8535E05A6                  42.0
# 9644  56F64A95-0406-4C4F-A8F6-0136659E0820                  42.0
#
#       DatosOperacion.UsuarioCreacion DatosOperacion.IpCreacion  \
# 9633                     890903790.0            192.168.97.252
# ...

# %%
equal_43['DatosOperacion.NumeroDocumentoEmpleador'] == 1105684208
# Out:
# 9633      False
# 9634      False
# 9638      False
# 9641      False
# 9644      False
#           ...
# 989671    False
# 989672    False
# 989673    False
# 989674    False
# 989676    False
# Name: DatosOperacion.NumeroDocumentoEmpleador, Length: 619132, dtype: bool

# %%
equal_43[equal_43['DatosOperacion.NumeroDocumentoEmpleador'] == 900432546]
# Out:
# Empty DataFrame
# ...

# %%
df.head(10)
# Out:
#           ID   FechaOperacion  ServicioOrigen  ServicioDestino  \
# 0  540137257  16/05/2022 1:39            1001             1002
# 1  540137262  16/05/2022 1:39            1001             1002
# 2  540137268  16/05/2022 1:39            1001             1002
# 3  540137276  16/05/2022 1:39            1001             1002
# 4  540137285  16/05/2022 1:39            1001             1002
# 5  540137288  16/05/2022 1:39            1001             1002
# 6  540137298  16/05/2022 1:39            1001             1002
# 7  540137302  16/05/2022 1:39            1001             1002
# 8  540137310  16/05/2022 1:39            1001             1002
# 9  540137315  16/05/2022 1:39            1001             1002
#
#                           Identificador  DatosOperacion.IdArl  \
# 0  0DD83FAC-B7A3-436D-809B-E110932B7974                  43.0
# 1  54278FCA-FDEA-4A0E-89F5-F8A6702D3AA2                  43.0
# 2  1580CE13-DC38-4D41-82AF-4244DB93E0DD                  43.0
# ...

# %%
df['DatosOperacion.NumeroDocumentoEmpleador'] == 1105684208
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 993458    False
# 993459    False
# 993460    False
# 993461    False
# 993462    False
# Name: DatosOperacion.NumeroDocumentoEmpleador, Length: 993463, dtype: bool

# %%
df[df['DatosOperacion.NumeroDocumentoEmpleador'] == '1105684208']
# Out:
#                ID    FechaOperacion  ServicioOrigen  ServicioDestino  \
# 232355  542604657  17/05/2022 19:01            2001             2002
# 232358  542604677  17/05/2022 19:01            3001             3002
# 232359  542604687  17/05/2022 19:01            7001             7002
# 349243  543547450  18/05/2022 12:00            1001             1002
# 784191  547611923  20/05/2022 16:03            7001             7002
# 785390  547624165  20/05/2022 16:15            7001             7002
# 786643  547635649  20/05/2022 16:27            7001             7002
# 787316  547641460  20/05/2022 16:31            7001             7002
#
#                                Identificador  DatosOperacion.IdArl  \
# 232355  7DF78B71-9EAB-4C98-B088-3D410B6FC7B1                  42.0
# 232358  5CF92E4C-C542-4DD0-8EDE-1D81645AF4CB                  42.0
# 232359  DA8749AA-9375-4DA2-BFBC-ED720F46BA52                  42.0
# 349243  F6458205-5666-47EC-BEB3-21FC3820C127                  42.0
# ...

# %%
df[['DatosOperacion.NumeroDocumentoEmpleador', 'ServicioOrigen'], & ['DatosOperacion.NumeroDocumentoEmpleador'] == ''1105684208'']
# Out:
#   Input In [55]
#     df[['DatosOperacion.NumeroDocumentoEmpleador', 'ServicioOrigen'], & ['DatosOperacion.NumeroDocumentoEmpleador'] == ''1105684208'']
#                                                                       ^
# SyntaxError: invalid syntax
